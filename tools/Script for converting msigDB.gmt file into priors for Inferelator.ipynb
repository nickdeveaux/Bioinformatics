# %% [markdown]
# ## Script for creating priors matrix
#
# This is used for converting the gmt file downloaded from Broad here into priors:
# http://software.broadinstitute.org/gsea/msigdb/collections.jsp
# Priors are either 1, -1, or, most likely, 0 (it's a sparse network)

# %% [markdown]
# To run this , I had to downoad the msigDB full 5.1 gmt file, and replace certain problematic genes with their more common names: ACCN1 with ASIC1, PIDD with PIDD1.

# %%
import csv
import itertools

inferelator_file = "../../Dropbox (Simons Foundation)/Priors_For_Inferelator.csv"
msigdb_file = "/Users/ndeveaux/Downloads/msigdb.v5.1.symbols.gmt"
stop_text = 'The following sets were evaluated, but determined to be lacking:'
HOMfile = '/Users/ndeveaux/Dev/ThirdParty/mu2hu/HOM_MouseHumanSequence.rpt'

# %%
all_targets = {}
selected_targets_plus = {}
selected_targets_minus = {}

# %%
""" Thanks Emily Miraldi for this code snippet taken from parseMouseGeneHomologs.py

This follows the Jax MGI database instructions:  
http://www.informatics.jax.org/faq/ORTH_dload.shtml
to download a .rpt file that contains mouse - human ortholog mappings

"""

muhuDic = dict() # keys = mouse, item = list of human genes
humuDic = dict() # keys = human, item = list of mouse genes

orthIn = open(HOMfile,'r')
orthNums = list()
muList = list()
huList = list()		
for line in itertools.islice(orthIn,1,None):
	lineInf = list()
	lineInf = line.strip('\n').split('\t')
	orthNum = lineInf[0]
	species = lineInf[1]
	symbol = lineInf[3]
	if orthNum not in orthNums: # first line for this ortholog
		for gene in muList:
			muhuDic[gene] = huList
		for gene in huList:
			humuDic[gene] = muList
		muList = list()
		huList = list()		
		orthNums.append(orthNum)
	if species == 'human':
		huList.append(symbol)
	else:
		muList.append(symbol)

# %%
def convert_human_to_mouse(target, organism):
    if target not in muhuDic:
        # print target + ' not found in mouse dictionary'
        if target not in humuDic:
            print target + ' not found in human dictionary either. Aborting'
            # return null if this is a human geneset and an ortholog can't be found
            if organism == 'H':
                print 'unpa' + 'ralleled human gene'
                return
            return target
        else:
            mouse_equivalent = humuDic[target]
            if len(mouse_equivalent) >= 1:
                return mouse_equivalent[0]
            else:
                print 'unusual mouse equivalent, length not 1: ' + str(mouse_equivalent)
                return target

# %%
def convert_row_to_target(row):
    geneset_id = row[0]
    transcription_factor = row[2].title()
    notes = row[8]
    organism = row[5]
    # A few assumptions need to be met in order to populate the table: not a KnockIn, double TF, or non-Up regulated
    if geneset_id[-3:] == '_UP':
        if 'KnockIn' not in notes:
            if '&' not in transcription_factor:
                # create union of past sets. 
                targets = [convert_human_to_mouse(x, organism) for x in all_targets[geneset_id]]
                print 'UP found: ' + geneset_id
                if targets != None:
                    if transcription_factor in selected_targets_minus:
                        selected_targets_minus[transcription_factor] = targets + selected_targets_minus[transcription_factor]
                    else:
                        selected_targets_minus[transcription_factor] = targets
                down_id = geneset_id.replace('UP', 'DN')
                if down_id in all_targets:
                    print 'DOWN found: ' + down_id
                    targets = [convert_human_to_mouse(x, organism) for x in all_targets[down_id]]
                    if targets != None:
                        if transcription_factor in selected_targets_plus:
                            selected_targets_plus[transcription_factor] = selected_targets_plus[transcription_factor] + targets
                        else:
                            selected_targets_plus[transcription_factor] = targets
                else:
                    print 'missing down-regulated KO geneset for geneset_id: {}'.format(geneset_id)
            else:
                print 'Double KO, & symbol, found in notes for {}'.format(geneset_id)
        else:
            print 'KnockIn found in notes for {}'.format(geneset_id)
    else:
        print 'unexpected format in geneset_id: {} missing UP'.format(geneset_id)

# %%
with open(msigdb_file) as f:
    g = f.read() 
    for line in g.split('\n'):
        tab_split = line.split('\t')
        all_targets[tab_split[0]] = tab_split[2:]

# %%
with open(inferelator_file, 'rb') as csvfile:
    f = csv.reader(csvfile, delimiter = ',')
    for row in f:
        if row[0] == stop_text:
            break
        convert_row_to_target(row)
# Out:
# unexpected format in geneset_id: ID missing UP
# unusual mouse equivalent, length not 1: []
# C15orf2 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# PROL1 not found in human dictionary either. Aborting
# PSG5 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# CST4 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# UP found: ATM_DN.V1_UP
# DOWN found: ATM_DN.V1_DN
# unusual mouse equivalent, length not 1: []
# LOC51190 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# C17orf88 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# POM121L9P not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# CES1P1 not found in human dictionary either. Aborting
# SPAG11A not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# HUMBINDC not found in human dictionary either. Aborting
# ZNF137P not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# HMHB1 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# KCNE1 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# LRRC48 not found in human dictionary either. Aborting
# PTPLA not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# ALDOAP2 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# C21orf63 not found in human dictionary either. Aborting
# C7orf36 not found in human dictionary either. Aborting
# C19orf10 not found in human dictionary either. Aborting
# CCDC76 not found in human dictionary either. Aborting
# LOC100128727 not found in human dictionary either. Aborting
# C12orf28 not found in human dictionary either. Aborting
# MEF2BNB not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# FOXE3 not found in human dictionary either. Aborting
# WDR16 not found in human dictionary either. Aborting
# KRTAP19-1 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# INADL not found in human dictionary either. Aborting
# ATPBD4 not found in human dictionary either. Aborting
# KRTAP19-5 not found in human dictionary either. Aborting
# KIAA1530 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# C9orf80 not found in human dictionary either. Aborting
# C20orf4 not found in human dictionary either. Aborting
# UP found: GSE18148_CBFB_KO_VS_WT_TREG_UP
# DOWN found: GSE18148_CBFB_KO_VS_WT_TREG_DN
# KIAA1407 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# EFTUD1 not found in human dictionary either. Aborting
# LOC100506540 not found in human dictionary either. Aborting
# MADCAM1 not found in human dictionary either. Aborting
# CCDC165 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# C11orf67 not found in human dictionary either. Aborting
# LPHN2 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# N6AMT2 not found in human dictionary either. Aborting
# MCART1 not found in human dictionary either. Aborting
# H19 not found in human dictionary either. Aborting
# TTC35 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# C16orf93 not found in human dictionary either. Aborting
# HRSP12 not found in human dictionary either. Aborting
# UP found: SUZUKI_CTCFL_TARGETS_UP
# missing down-regulated KO geneset for geneset_id: SUZUKI_CTCFL_TARGETS_UP
# C12orf24 not found in human dictionary either. Aborting
# GPR172A not found in human dictionary either. Aborting
# CYBASC3 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# PPPDE1 not found in human dictionary either. Aborting
# TH1L not found in human dictionary either. Aborting
# KLHDC5 not found in human dictionary either. Aborting
# C1orf65 not found in human dictionary either. Aborting
# KIAA1430 not found in human dictionary either. Aborting
# KIAA1530 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# FBXO38 not found in human dictionary either. Aborting
# C9orf150 not found in human dictionary either. Aborting
# C9orf23 not found in human dictionary either. Aborting
# IPW not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# UP found: GS
not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# FAM190B not found in human dictionary either. Aborting
# XIST not found in human dictionary either. Aborting
# RDBP not found in human dictionary either. Aborting
# C10orf26 not found in human dictionary either. Aborting
# LINC00116 not found in human dictionary either. Aborting
# AGPAT9 not found in human dictionary either. Aborting
# PTPLB not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# ZC3H13 not found in human dictionary either. Aborting
# EIF2C1 not found in human dictionary either. Aborting
# ROD1 not found in human dictionary either. Aborting
# IGKC not found in human dictionary either. Aborting
# FAM108B1 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# NADKD1 not found in human dictionary either. Aborting
# ACPL2 not found in human dictionary either. Aborting
# C17orf76 not found in human dictionary either. Aborting
# PPP1R2P1 not found in human dictionary either. Aborting
# WHSC2 not found in human dictionary either. Aborting
# LINC00094 not found in human dictionary either. Aborting
# FAM105B not found in human dictionary either. Aborting
# C11orf30 not found in human dictionary either. Aborting
# MST4 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# C9orf89 not found in human dictionary either. Aborting
# LOC152217 not found in human dictionary either. Aborting
# MLL5 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# UP found: GSE6875_WT_VS_FOXP3_KO_TREG_UP
# DOWN found: GSE6875_WT_VS_FOXP3_KO_TREG_DN
# PPFIA4 not found in human dictionary either. Aborting
# CTPS not found in human dictionary either. Aborting
# C10orf58 not found in human dictionary either. Aborting
# SNORD123 not found in human dictionary either. Aborting
# LOC550643 not found in human dictionary either. Aborting
# WDR96 not found in human dictionary either. Aborting
# FAM164A not found in human dictionary either. Aborting
# C9orf46 not found in human dictionary either. Aborting
# C11orf75 not found in human dictionary either. Aborting
# C6orf125 not found in human dictionary either. Aborting
# CCBL2 not found in human dictionary either. Aborting
# C4orf21 not found in human dictionary either. Aborting
# C12orf34 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# PRIC285 not found in human dictionary either. Aborting
# FAM100A not found in human dictionary either. Aborting
# C9orf95 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# UP found: GSE7219_WT_VS_NIK_NFKB2_KO_DC_UP
# DOWN found: GSE7219_WT_VS_NIK_NFKB2_KO_DC_DN
# CMAHP not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# LPHN1 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# GCET2 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# CCDC101 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# C17orf76 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# UP found: GSE7219_WT_VS_NIK_NFKB2_KO_LPS_AND_ANTI_CD40_STIM_DC_UP
# DOWN found: GSE7219_WT_VS_NIK_NFKB2_KO_LPS_AND_ANTI_CD40_STIM_DC_DN
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# C17orf63 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# CYBASC3 not found in human dictionary either. Aborting
# FAM176B not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# KRT10 not found in human dictionary either. Aborting
# KIAA0247 not found in human dictionary either. Aborting
# TENC1 not found in human dictionary either. Aborting
# PION not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# C15orf29 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# EIF2C4 not found in human dictionary either. Aborting
# MCART6 not found in human dictionary either. Aborting
# KIAA1598 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# KIAA1797 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# UTY not found in human dictionary either. Aborting
# IGHG1 not found in human dictionary either. Aborting
# OBFC2A not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# C5orf62 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# C10orf58 not found in human dictionary either. Aborting
# MIR22HG not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# C10orf125 not found in human dictionary either. Aborting
# GCFC1 not found in human dictionary either. Aborting
# KIAA1009 not found in human dictionary either. Aborting
# METTL21D not found in human dictionary either. Aborting
# C9orf156 not found in human dictionary either. Aborting
# UP found: GSE7460_FOXP3_MUT_VS_WT_ACT_TCONV_UP
# DOWN found: GSE7460_FOXP3_MUT_VS_WT_ACT_TCONV_DN
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# CCDC164 not found in human dictionary either. Aborting
# C16orf5 not found in human dictionary either. Aborting
# XIST not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# A2LD1 not found in human dictionary either. Aborting
# FAM123B not found in human dictionary either. Aborting
# ZNF238 not found in human dictionary either. Aborting
# KIAA0564 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# C5orf13 not found in human dictionary either. Aborting
# C11orf67 not found in human dictionary either. Aborting
# CCDC90A not found in human dictionary either. Aborting
# C11orf2 not found in human dictionary either. Aborting
# FAM5C not found in human dictionary either. Aborting
# PPPDE2 not found in human dictionary either. Aborting
# FAM164A not found in human dictionary either. Aborting
# TMEM146 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# KBTBD5 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# WAPAL not found in human dictionary either. Aborting
# RG9MTD2 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# C5orf62 not found in human dictionary either. Aborting
# C10orf58 not found in human dictionary either. Aborting
# UTY not found in human dictionary either. Aborting
# UP found: GSE7460_FOXP3_MUT_VS_WT_ACT_WITH_TGFB_TCONV_UP
# DOWN found: GSE7460_FOXP3_MUT_VS_WT_ACT_WITH_TGFB_TCONV_DN
# CD97 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# JHDM1D not found in human dictionary either. Aborting
# CCDC164 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# PCNX not found in human dictionary either. Aborting
# MCART1 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# unusual mouse equivalent, length not 1: []
# C5orf13 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# SUV420H1 not found in human dictionary either. Aborting
# LOC550643 not found in human dictionary either. Aborting
# XIST not found in human dictionary either. Aborting
# C12orf51 not found in human dictionary either. Aborting
# unusual mouse equivalent, length not 1: []
# unexpected format in geneset_id:  missing UP
# unexpected format in geneset_id:  missing UP
# unexpected format in geneset_id:  missing UP

# %%
all_targets = set([item for sublist in selected_targets_minus.values() + selected_targets_plus.values() for item in sublist])

# %%
with open('TF_targets_list.csv', 'wb') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',')
    spamwriter.writerow([''] + [key for key in selected_targets_plus])
    for item in all_targets:
        row = [item]
        for key in set(selected_targets_plus.keys() + selected_targets_minus.keys()):
            value = [0, 0]
            if key in selected_targets_plus:
                value[0] = selected_targets_plus[key].count(item)
            if key in selected_targets_minus:
                value[1] = -1 * selected_targets_minus[key].count(item)
            if not all(value):
                value = [0]
            row.append(','.join(map(str, value)))
        spamwriter.writerow(row)

# %%
with open('TF_targets_sum.csv', 'wb') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',')
    spamwriter.writerow([''] + [key for key in selected_targets_plus])
    for item in all_targets:
        row = [item]
        for key in set(selected_targets_plus.keys() + selected_targets_minus.keys()):
            value = [0, 0]
            if key in selected_targets_plus:
                value[0] = selected_targets_plus[key].count(item)
            if key in selected_targets_minus:
                value[1] = -1 * selected_targets_minus[key].count(item)
            if item == 'Wls' and value[1] == -2:
                import pdb; pdb.set_trace()
            row.append(str(sum(value)))
        spamwriter.writerow(row)
# Out:
# > <ipython-input-226-799dda406478>(14)<module>()
# -> row.append(str(sum(value)))
# (Pdb) l
#   9  	                value[0] = selected_targets_plus[key].count(item)
#  10  	            if key in selected_targets_minus:
#  11  	                value[1] = -1 * selected_targets_minus[key].count(item)
#  12  	            if item == 'Wls' and value[1] == -2:
#  13  	                import pdb; pdb.set_trace()
#  14  ->	            row.append(str(sum(value)))
#  15  	        spamwriter.writerow(row)
#  16
# [EOF]
# (Pdb) str(sum(value))
# '-1'
# (Pdb) item
# 'Wls'
# (Pdb) key
# 'Pparg'
# (Pdb) c
